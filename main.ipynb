# %%
import os
import pandas as pd
import numpy as np
import faiss
from faiss import write_index
import numpy as np
import pandas as pd
import torch
from transformers import AutoTokenizer, AutoModel
from torch.utils.data import Dataset
from torch.utils.data import DataLoader
from tqdm import tqdm
from config import CFG
import gradio as gr
import requests
import json
import GUI
from __future__ import absolute_import
from __future__ import division
from __future__ import print_function

import numpy as np


def _lcs(string, sub):
    """
    Computes longest common subsequence (LCS) for a pair of tokenized strings
    :param string : list of str : tokens from a string split using whitespace
    :param sub : list of str : shorter string, also split using whitespace
    :returns: length (list of int): length of the LCS between the two strings
    """

    if len(string) < len(sub):
        sub, string = string, sub

    str_len, sub_len = len(string), len(sub)
    lengths = [[0 for _ in range(sub_len + 1)] for _ in range(str_len + 1)]

    for j in range(1, sub_len + 1):
        for i in range(1, str_len + 1):
            if string[i - 1] == sub[j - 1]:
                lengths[i][j] = lengths[i - 1][j - 1] + 1
            else:
                lengths[i][j] = max(lengths[i - 1][j], lengths[i][j - 1])

    return lengths[str_len][sub_len]


class Rouge(object):
    """
    Class for computing ROUGE-L score for a set of 
    candidate sentences for the MS COCO test set
    """

    def __init__(self):
        # vrama91: updated the value below based on discussion with Hovey
        self.beta = 1.2

    def calc_score(self, candidate, refs):
        """
        Compute ROUGE-L score given one candidate and references for an image
        :param candidate: str : candidate sentence to be evaluated
        :param refs: list of str : COCO reference sentences for the particular image to be evaluated
        :returns score: int (ROUGE-L score for the candidate evaluated against references)
        """

        assert(len(candidate) == 1)
        assert(len(refs) > 0)

        prec = []
        rec = []

        # split into tokens
        token_c = candidate[0].split()

        for reference in refs:
            # split into tokens
            token_r = reference.split()
            # compute the longest common subsequence
            lcs = _lcs(token_r, token_c)
            prec.append(lcs / float(len(token_c)))
            rec.append(lcs / float(len(token_r)))

        prec_max = max(prec)
        rec_max = max(rec)

        if prec_max != 0 and rec_max != 0:
            score = ((1 + self.beta ** 2) * prec_max * rec_max) / \
                float(rec_max + self.beta ** 2 * prec_max)
        else:
            score = 0.0

        return score

    def compute_score(self, gts, res):
        """
        Computes Rouge-L score given a set of reference and 
        candidate sentences for the dataset.
        :param gts: dict : ground_truth
        :param res: dict : results of predict
        :returns: average_score: float (mean ROUGE-L score)
        """

        score = []

        for idx in sorted(gts.keys()):
            hypo = res[idx]
            ref = gts[idx]
            score.append(self.calc_score(hypo, ref))

            # Sanity check
            assert(isinstance(hypo, list))
            assert(isinstance(ref, list))
            assert(len(hypo) == 1)
            assert(len(ref) > 0)

        average_score = np.mean(np.array(score))

        # convert to percentage
        return 100 * average_score, np.array(score)

    @staticmethod
    def method():
        return "ROUGE-L"

# %%
import pandas as pd

# Assuming your CSV file is named 'data.csv'
df = pd.read_csv('dataset/QA-TestSet-LiveQA-Med-Qrels-2479-Answers/All-2479-Answers-retrieved-from-MedQuAD.csv', engine='python')
print(df.head())

# Assuming 'df' is your original DataFrame

# Regular expression to match the structure of the 'Answer' column
pattern = r'Question:\s*(.*?)\s*URL:\s*(https?://[^\s]+)\s*Answer:\s*(.*)'

# Extracting the components into a new DataFrame
questions_df = df['Answer'].str.extract(pattern, expand=True)
questions_df.columns = ['Question', 'URL', 'Answer']

questions_df['Question'] = questions_df['Question'].str.replace(r'\(Also called:.*?\)', '', regex=True).str.strip()
# Out:
#                 AnswerID                                             Answer
# 0  ADAM_0003147_Sec1.txt  Question: What is (are) Polycystic ovary syndr...
# 1  ADAM_0003147_Sec2.txt  Question: What causes Polycystic ovary syndrom...
# 2  ADAM_0002818_Sec2.txt  Question: What causes Noonan syndrome ?\r\nURL...
# 3  ADAM_0002818_Sec7.txt  Question: What are the complications of Noonan...
# 4  ADAM_0002818_Sec9.txt  Question: How to prevent Noonan syndrome ?\r\n...

# %%
questions_df.head(5)
# Out:
#                                           Question  \
# 0        What is (are) Polycystic ovary syndrome ?
# 1          What causes Polycystic ovary syndrome ?
# 2                    What causes Noonan syndrome ?
# 3  What are the complications of Noonan syndrome ?
# 4                 How to prevent Noonan syndrome ?
#
#                                                  URL  \
# 0  https://www.nlm.nih.gov/medlineplus/ency/artic...
# 1  https://www.nlm.nih.gov/medlineplus/ency/artic...
# 2  https://www.nlm.nih.gov/medlineplus/ency/artic...
# 3  https://www.nlm.nih.gov/medlineplus/ency/artic...
# 4  https://www.nlm.nih.gov/medlineplus/ency/artic...
#
#                                               Answer
# 0  Polycystic ovary syndrome is a condition in wh...
# 1  PCOS is linked to changes in hormone levels th...
# 2  Noonan syndrome is linked to defects in severa...
# 3  - Buildup of fluid in tissues of body (lymphed...
# 4  Couples with a family history of Noonan syndro...

# %%
respuestas=questions_df['Answer'].tolist()

# %%
print(Rouge().calc_score(['hola que tal'],['hola que tal estas cariño','hola mi amor','how are you?']))
# Out:
# 0.7176470588235294

# %%
import torch

# Verifica si CUDA está disponible
cuda_available = torch.cuda.is_available()

# Imprime si CUDA está disponible o no
print("CUDA disponible:", cuda_available)

# Imprime el dispositivo por defecto
if cuda_available:
    print("Dispositivo por defecto:", torch.cuda.get_device_name(torch.cuda.current_device()))
else:
    print("Dispositivo por defecto: CPU")
# Out:
# CUDA disponible: True
# Dispositivo por defecto: NVIDIA GeForce GTX 1650

# %%
client=GUI.MedicalChatBotGUI(model='llama2')

# %%
client.generate_faiss_db()
# CArga de datos y generacion de la BBDD vectorial
# Out:
# c:\Users\mario\.conda\envs\TFM\lib\site-packages\torch\_utils.py:831: UserWarning: TypedStorage is deprecated. It will be removed in the future and UntypedStorage will be the only storage class. This should only matter to you if you are using storages directly.  To access UntypedStorage directly, use tensor.untyped_storage() instead of tensor.storage()
#   return self.fget.__get__(instance, owner)()
# 100%|██████████| 238/238 [01:20<00:00,  2.95it/s]
#                                                 question question_id  \
# 0      What is (are) A guide to clinical trials for c...   0000001-1
# 6                               What is (are) A1C test ?   0000003-1
# 8                       What is (are) Aarskog syndrome ?   0000004-1
# 9                         What causes Aarskog syndrome ?   0000004-2
# 10           What are the symptoms of Aarskog syndrome ?   0000004-3
# ...                                                  ...         ...
# 46972             What is (are) Von Willebrand Disease ?   0000139-1
# 46973               What causes Von Willebrand Disease ?   0000139-2
# 46974  What are the symptoms of Von Willebrand Disease ?   0000139-3
# 46975           How to diagnose Von Willebrand Disease ?   0000139-4
# 46976  What are the treatments for Von Willebrand Dis...   0000139-5
#
#          question_type                                             answer  \
# 0          information  If you have cancer, a clinical trial may be an...
# 6          information  A1C is a lab test that shows the average level...
# 8          information  Aarskog syndrome is a very rare disease that a...
# 9               causes  Aarskog syndrome is a genetic disorder that is...
# 10            symptoms  Symptoms of this condition include: Belly butt...
# ...                ...                                                ...
# 46972      information  Von Willebrand disease (VWD) is a bleeding dis...
# 46973           causes  Von Willebrand disease (VWD) is almost always ...
# 46974         symptoms  The signs and symptoms of von Willebrand disea...
# 46975  exams and tests  Early diagnosis of von Willebrand disease (VWD...
# 46976        treatment  Treatment for von Willebrand disease (VWD) is ...
#
#                                        focus   id source  \
# 0      A guide to clinical trials for cancer    1   ADAM
# 6                                   A1C test    3   ADAM
# 8                           Aarskog syndrome    4   ADAM
# 9                           Aarskog syndrome    4   ADAM
# 10                          Aarskog syndrome    4   ADAM
# ...                                      ...  ...    ...
# 46972                 Von Willebrand Disease  139  NHLBI
# 46973                 Von Willebrand Disease  139  NHLBI
# 46974                 Von Willebrand Disease  139  NHLBI
# 46975                 Von Willebrand Disease  139  NHLBI
# 46976                 Von Willebrand Disease  139  NHLBI
#
#                                                      url       cui  \
# 0      https://www.nlm.nih.gov/medlineplus/ency/patie...  C0006826
# 6      https://www.nlm.nih.gov/medlineplus/ency/artic...  C0456984
# 8      https://www.nlm.nih.gov/medlineplus/ency/artic...  C0175701
# 9      https://www.nlm.nih.gov/medlineplus/ency/artic...  C0175701
# 10     https://www.nlm.nih.gov/medlineplus/ency/artic...  C0175701
# ...                                                  ...       ...
# 46972  http://www.nhlbi.nih.gov/health/health-topics/...  C0042974
# 46973  http://www.nhlbi.nih.gov/health/health-topics/...  C0042974
# 46974  http://www.nhlbi.nih.gov/health/health-topics/...  C0042974
# 46975  http://www.nhlbi.nih.gov/health/health-topics/...  C0042974
# 46976  http://www.nhlbi.nih.gov/health/health-topics/...  C0042974
#
#       semanticType semanticGroup
# 0             T191     Disorders
# 6             T033     Disorders
# 8             T019     Disorders
# 9             T019     Disorders
# 10            T019     Disorders
# ...            ...           ...
# 46972         T047     Disorders
# 46973         T047     Disorders
# 46974         T047     Disorders
# 46975         T047     Disorders
# 46976         T047     Disorders
#
# [30367 rows x 11 columns]

# %%
demo = gr.ChatInterface(fn = client.make_inference, 
                        examples = ["What is diabetes?", "Is ginseng good for diabetes?", "What are the symptoms of diabetes?"], 
                        title = "Medical RAG Chatbot", 
                        description = "Medical RAG Chatbot is a chatbot that can help you with your medical queries. It is a rule-based chatbot that can answer your queries based on the information it has. It is not a replacement for a doctor. Please consult a doctor for any medical advice.",
                        )

# %%
demo.launch()
# Out:
# Running on local URL:  http://127.0.0.1:7860
#
# To create a public link, set `share=True` in `launch()`.
# <div><iframe src="http://127.0.0.1:7860/" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>
# Hey! I see you're interested in learning about poisonous plants. As a medical sciences bot, I can provide you with information on different types of poisonous plants and their effects on human health. Based on your query, I recommend checking out the following articles from the National Library of Medicine:
#
# 1. Poison ivy, oak, or sumac poisoning: This article provides information on the symptoms, treatment, and prevention of poison ivy, oak, or sumac exposure. It's important to note that small amounts of sap can remain under a person's fingernails for several days, so thorough cleaning is essential to remove the toxin.
# 2. Chinese restaurant syndrome: This article discusses the myths and facts surrounding MSG (monosodium glutamate), a food additive that has been linked to various symptoms in some people. According to the FDA, MSG is generally considered safe for most people when consumed in foods at normal levels.
# 3. Poinsettia plant exposure: This article addresses common concerns about the toxicity of poinsettia plants during the holiday season. While the plant itself is not poisonous, eating any part of it can cause gastrointestinal upset. If you or someone you know has ingested a large amount of poinsettia leaves or stems, call your local emergency number or the national toll-free Poison Help hotline for assistance.
# 4. Myristica oil poisoning: This article provides information on the symptoms and treatment of myristica oil (also known as nutmeg) poisoning. Myristica oil is highly toxic, so it's important to seek medical attention immediately if ingested in large quantities.
# 5. Oleander poisoning: This article discusses the signs and symptoms of oleander poisoning, which can occur when someone eats the flowers or chews the leaves or stems of the oleander plant. If you suspect exposure to oleander, call your local emergency number or the national toll-free Poison Help hotline for assistance.
#
# I hope these recommendations are helpful! Remember, if you have any concerns about poisoning or exposure to harmful substances, always seek medical attention immediately.
# Based on your queries, it seems that you are looking for information about diabetes symptoms, particularly type 2 diabetes symptoms. Here is a targeted recommendation for you:
#
# If you suspect you may have type 2 diabetes, it's essential to consult with your doctor as soon as possible. While some people may not experience any symptoms, early detection can help prevent or delay the complications of diabetes. The symptoms of type 2 diabetes can be subtle and may include frequent urination, thirst, hunger, fatigue, blurry vision, and tingling sensations in the feet. If you are over 45 years old, overweight, or have a family history of diabetes, it's crucial to get tested for type 2 diabetes.
#
# In addition to consulting with your doctor, there are some lifestyle changes you can make to help manage your risk factors for type 2 diabetes:
#
# 1. Maintain a healthy weight: If you are overweight or obese, losing weight can significantly reduce your risk of developing type 2 diabetes.
# 2. Exercise regularly: Engaging in physical activity can improve insulin sensitivity and help regulate blood sugar levels.
# 3. Eat a balanced diet: Aim to consume a diet rich in whole grains, fruits, vegetables, lean proteins, and healthy fats, such as those found in nuts, seeds, avocados, and olive oil.
# 4. Reduce stress: Chronic stress can increase your risk of developing type 2 diabetes. Engage in stress-reducing activities, such as yoga, meditation, or deep breathing exercises.
# 5. Get enough sleep: Lack of sleep can increase your risk of developing type 2 diabetes. Aim for 7-8 hours of sleep per night.
#
# By making these lifestyle changes and getting tested for type 2 diabetes, you can significantly reduce your risk of developing this disease and manage its complications if you are already diagnosed. Remember, early detection and prevention are key to maintaining good health.
